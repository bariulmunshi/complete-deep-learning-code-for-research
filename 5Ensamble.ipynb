# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-40a5903b88ccf81a4b5dca6b4c513f3203dec43a0013d239ec2a40a2' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/cnn/local/brain_tumor/
# Out:
# /content/drive/MyDrive/cnn/local/brain_tumor

# %%
ls -la
# Out:
# total 17
# -rw------- 1 root root  182 May  9 17:59 config.json
# drwx------ 2 root root 4096 May  9 17:42 Ensemble/
# drwx------ 2 root root 4096 May 10 06:08 MODEL_DIR/
# drwx------ 2 root root 4096 Jun  5 16:50 models/
# drwx------ 2 root root 4096 May 10 09:12 MODELS/

# %% [markdown]
# # PARAMETERS

# %%
import os 
from glob import glob 
MODELS=[_path for _path in glob(os.path.join(os.getcwd(),"MODELS","*.*"))]
DATA_FOLDER =    "content/drive/MyDrive/braintumor/tfrecords"
print("--------------------AVAILABLE MODELS----------------------------------------------")
print("----------------------------------------------------------------------------------")
model_names=[]
for MODEL in MODELS:
  model_name=os.path.basename(MODEL).split(".")[0]
  print(model_name)
  model_names.append(model_name)
  print("----------------------------------------------------------------------------------")
MODEL_NAME="_".join(model_names)
MODEL_NAME="ensamble_"+MODEL_NAME
print(MODEL_NAME)
# Out:
# --------------------AVAILABLE MODELS----------------------------------------------
# ----------------------------------------------------------------------------------
# densenet201
# ----------------------------------------------------------------------------------
# xception
# ----------------------------------------------------------------------------------
# seresnext101
# ----------------------------------------------------------------------------------
# inceptionv3
# ----------------------------------------------------------------------------------
# ensamble_densenet201_xception_seresnext101_inceptionv3

# %%
import os 
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048  
MODEL_DIR   =    os.path.join(os.getcwd(),"Ensemble",f'{MODEL_NAME}') 
if not os.path.exists(MODEL_DIR):
  os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,"model.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}/'

print(GCS_PATH)
print(WEIGHT_PATH)
print(MODEL_DIR)
# Out:
# gs://kds-40a5903b88ccf81a4b5dca6b4c513f3203dec43a0013d239ec2a40a2/content/drive/MyDrive/braintumor/tfrecords/
# /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['Brain', 'No_tumor'],
#  'nb_channels': 3,
#  'nb_classes': 2,
#  'nb_eval_data': 1120,
#  'nb_train_data': 5296}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf 
import os 


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.8.2
# Running on TPU  grpc://10.33.231.178:8470
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.33.231.178:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.33.231.178:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 41 8

# %% [markdown]
# ## Data input function

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn

def get_model(model_path):
  model_name=os.path.basename(model_path).split(".")[0]
  if "EfficientNet" not in model_name:
    classifier, _ = Classifiers.get(model_name)
  else:
    classifier=getattr(efn,model_name)
  net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights=None)
  for layer in net.layers:
      layer.trainable = False
  
  inp=net.input
  x=net.output
  x=tf.keras.layers.GlobalAveragePooling2D()(x)
  x=tf.keras.layers.Dropout(0.1)(x)
  x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
  model=tf.keras.Model(inputs=inp,outputs=x)
  model.load_weights(model_path)
  print(f"Loaded:{model_path}")
  return model,model_name

def ensamble_model(model_paths):
  models=[]
  names=[]
  for model_path in model_paths:
    model,mname=get_model(model_path)
    models.append(model)
    names.append(mname)
  ensamble_inputs=[model.input for model in models]
  ensamble_outputs=[model.output for model in models]
  merge=tf.keras.layers.Concatenate()(ensamble_outputs)
  out=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(merge)
  model=tf.keras.models.Model(inputs=ensamble_inputs,outputs=out)
  print(ensamble_inputs)
  return model

with strategy.scope():
    model=ensamble_model(MODELS)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )
# Out:
# Loaded:/content/drive/MyDrive/cnn/local/brain_tumor/MODELS/densenet201.h5
# Loaded:/content/drive/MyDrive/cnn/local/brain_tumor/MODELS/xception.h5
# Loaded:/content/drive/MyDrive/cnn/local/brain_tumor/MODELS/seresnext101.h5
# Loaded:/content/drive/MyDrive/cnn/local/brain_tumor/MODELS/inceptionv3.h5
# [<KerasTensor: shape=(None, 256, 256, 3) dtype=float32 (created by layer 'input_1')>, <KerasTensor: shape=(None, 256, 256, 3) dtype=float32 (created by layer 'input_2')>, <KerasTensor: shape=(None, 256, 256, 3) dtype=float32 (created by layer 'input')>, <KerasTensor: shape=(None, 256, 256, 3) dtype=float32 (created by layer 'input_3')>]

# %%
names=[]
for n in model.inputs:
  names.append(n.name)
  print(n.name) 
#model.get_layer(index =1).name
# Out:
# input_1
# input_2
# input
# input_3

# %%
def data_input_fn(mode): 
    '''
      This Function generates data from gcs
    '''
    
    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }    
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))
        
        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        images={}
        for model_name in names:
          images[model_name]=image
        return images,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
  print(x.keys())
  for model_name in names:
      print(model_name)
      print(x[f"{model_name}"].shape)
      data=np.squeeze(x[f"{model_name}"][0])
      plt.imshow(data)
      plt.show()
      print('Image Batch Shape:',x[f"{model_name}"].shape)
      print('Target Batch Shape:',y.shape)
      print(LABELS)
      print(y[0])
      break
# Out:
# dict_keys(['input_1', 'input_2', 'input', 'input_3'])
# input_1
# (128, 256, 256, 3)
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 2)
# ['Brain', 'No_tumor']
# tf.Tensor([1. 0.], shape=(2,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True, 
                                                  verbose=1, 
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15, 
                                                  verbose=1, 
                                                  mode = 'auto') 

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1, 
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 41/41 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.5478
# Epoch 1: val_loss improved from inf to 0.60434, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 358s 4s/step - loss: 0.7092 - accuracy: 0.5478 - val_loss: 0.6043 - val_accuracy: 0.6748 - lr: 1.0000e-04
# Epoch 2/250
# 41/41 [==============================] - ETA: 0s - loss: 0.5021 - accuracy: 0.8838
# Epoch 2: val_loss improved from 0.60434 to 0.56095, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.5021 - accuracy: 0.8838 - val_loss: 0.5609 - val_accuracy: 0.7920 - lr: 1.0000e-04
# Epoch 3/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.9350
# Epoch 3: val_loss improved from 0.56095 to 0.55411, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.4779 - accuracy: 0.9350 - val_loss: 0.5541 - val_accuracy: 0.7920 - lr: 1.0000e-04
# Epoch 4/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4683 - accuracy: 0.9423
# Epoch 4: val_loss improved from 0.55411 to 0.54834, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.4683 - accuracy: 0.9423 - val_loss: 0.5483 - val_accuracy: 0.8076 - lr: 1.0000e-04
# Epoch 5/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.9472
# Epoch 5: val_loss improved from 0.54834 to 0.54222, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 53s 1s/step - loss: 0.4590 - accuracy: 0.9472 - val_loss: 0.5422 - val_accuracy: 0.8047 - lr: 1.0000e-04
# Epoch 6/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4523 - accuracy: 0.9480
# Epoch 6: val_loss improved from 0.54222 to 0.53641, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.4523 - accuracy: 0.9480 - val_loss: 0.5364 - val_accuracy: 0.8145 - lr: 1.0000e-04
# Epoch 7/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.9522
# Epoch 7: val_loss improved from 0.53641 to 0.53423, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.4461 - accuracy: 0.9522 - val_loss: 0.5342 - val_accuracy: 0.8232 - lr: 1.0000e-04
# Epoch 8/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4387 - accuracy: 0.9558
# Epoch 8: val_loss improved from 0.53423 to 0.52492, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.4387 - accuracy: 0.9558 - val_loss: 0.5249 - val_accuracy: 0.8242 - lr: 1.0000e-04
# Epoch 9/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4323 - accuracy: 0.9562
# Epoch 9: val_loss improved from 0.52492 to 0.52451, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 61s 2s/step - loss: 0.4323 - accuracy: 0.9562 - val_loss: 0.5245 - val_accuracy: 0.8184 - lr: 1.0000e-04
# Epoch 10/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.9556
# Epoch 10: val_loss improved from 0.52451 to 0.51637, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.4255 - accuracy: 0.9556 - val_loss: 0.5164 - val_accuracy: 0.8242 - lr: 1.0000e-04
# Epoch 11/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4196 - accuracy: 0.9615
# Epoch 11: val_loss did not improve from 0.51637
# 41/41 [==============================] - 17s 422ms/step - loss: 0.4196 - accuracy: 0.9615 - val_loss: 0.5193 - val_accuracy: 0.8203 - lr: 1.0000e-04
# Epoch 12/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4139 - accuracy: 0.9607
# Epoch 12: val_loss improved from 0.51637 to 0.51012, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.4139 - accuracy: 0.9607 - val_loss: 0.5101 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 13/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.9598
# Epoch 13: val_loss improved from 0.51012 to 0.50909, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.4094 - accuracy: 0.9598 - val_loss: 0.5091 - val_accuracy: 0.8262 - lr: 1.0000e-04
# Epoch 14/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4012 - accuracy: 0.9667
# Epoch 14: val_loss improved from 0.50909 to 0.50487, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 57s 1s/step - loss: 0.4012 - accuracy: 0.9667 - val_loss: 0.5049 - val_accuracy: 0.8242 - lr: 1.0000e-04
# Epoch 15/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3967 - accuracy: 0.9647
# Epoch 15: val_loss improved from 0.50487 to 0.50294, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 58s 1s/step - loss: 0.3967 - accuracy: 0.9647 - val_loss: 0.5029 - val_accuracy: 0.8193 - lr: 1.0000e-04
# Epoch 16/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3928 - accuracy: 0.9638
# Epoch 16: val_loss improved from 0.50294 to 0.49741, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 58s 1s/step - loss: 0.3928 - accuracy: 0.9638 - val_loss: 0.4974 - val_accuracy: 0.8242 - lr: 1.0000e-04
# Epoch 17/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3861 - accuracy: 0.9668
# Epoch 17: val_loss did not improve from 0.49741
# 41/41 [==============================] - 17s 426ms/step - loss: 0.3861 - accuracy: 0.9668 - val_loss: 0.4978 - val_accuracy: 0.8193 - lr: 1.0000e-04
# Epoch 18/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3815 - accuracy: 0.9676
# Epoch 18: val_loss improved from 0.49741 to 0.49307, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 57s 1s/step - loss: 0.3815 - accuracy: 0.9676 - val_loss: 0.4931 - val_accuracy: 0.8262 - lr: 1.0000e-04
# Epoch 19/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.9695
# Epoch 19: val_loss improved from 0.49307 to 0.48515, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 59s 1s/step - loss: 0.3769 - accuracy: 0.9695 - val_loss: 0.4852 - val_accuracy: 0.8320 - lr: 1.0000e-04
# Epoch 20/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.9712
# Epoch 20: val_loss improved from 0.48515 to 0.48460, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 60s 1s/step - loss: 0.3714 - accuracy: 0.9712 - val_loss: 0.4846 - val_accuracy: 0.8340 - lr: 1.0000e-04
# Epoch 21/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.9712
# Epoch 21: val_loss improved from 0.48460 to 0.48189, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 63s 2s/step - loss: 0.3661 - accuracy: 0.9712 - val_loss: 0.4819 - val_accuracy: 0.8311 - lr: 1.0000e-04
# Epoch 22/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3624 - accuracy: 0.9697
# Epoch 22: val_loss improved from 0.48189 to 0.48088, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.3624 - accuracy: 0.9697 - val_loss: 0.4809 - val_accuracy: 0.8311 - lr: 1.0000e-04
# Epoch 23/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3580 - accuracy: 0.9701
# Epoch 23: val_loss improved from 0.48088 to 0.47480, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.3580 - accuracy: 0.9701 - val_loss: 0.4748 - val_accuracy: 0.8359 - lr: 1.0000e-04
# Epoch 24/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3501 - accuracy: 0.9754
# Epoch 24: val_loss improved from 0.47480 to 0.47274, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.3501 - accuracy: 0.9754 - val_loss: 0.4727 - val_accuracy: 0.8369 - lr: 1.0000e-04
# Epoch 25/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3500 - accuracy: 0.9718
# Epoch 25: val_loss did not improve from 0.47274
# 41/41 [==============================] - 17s 423ms/step - loss: 0.3500 - accuracy: 0.9718 - val_loss: 0.4739 - val_accuracy: 0.8281 - lr: 1.0000e-04
# Epoch 26/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3428 - accuracy: 0.9752
# Epoch 26: val_loss improved from 0.47274 to 0.46735, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.3428 - accuracy: 0.9752 - val_loss: 0.4673 - val_accuracy: 0.8369 - lr: 1.0000e-04
# Epoch 27/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3387 - accuracy: 0.9762
# Epoch 27: val_loss improved from 0.46735 to 0.46709, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 59s 1s/step - loss: 0.3387 - accuracy: 0.9762 - val_loss: 0.4671 - val_accuracy: 0.8311 - lr: 1.0000e-04
# Epoch 28/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.9769
# Epoch 28: val_loss improved from 0.46709 to 0.46431, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.3360 - accuracy: 0.9769 - val_loss: 0.4643 - val_accuracy: 0.8291 - lr: 1.0000e-04
# Epoch 29/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.9777
# Epoch 29: val_loss improved from 0.46431 to 0.46127, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.3294 - accuracy: 0.9777 - val_loss: 0.4613 - val_accuracy: 0.8398 - lr: 1.0000e-04
# Epoch 30/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.9783
# Epoch 30: val_loss improved from 0.46127 to 0.45634, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.3273 - accuracy: 0.9783 - val_loss: 0.4563 - val_accuracy: 0.8369 - lr: 1.0000e-04
# Epoch 31/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3226 - accuracy: 0.9773
# Epoch 31: val_loss did not improve from 0.45634
# 41/41 [==============================] - 18s 431ms/step - loss: 0.3226 - accuracy: 0.9773 - val_loss: 0.4594 - val_accuracy: 0.8262 - lr: 1.0000e-04
# Epoch 32/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3182 - accuracy: 0.9802
# Epoch 32: val_loss improved from 0.45634 to 0.45138, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.3182 - accuracy: 0.9802 - val_loss: 0.4514 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 33/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3148 - accuracy: 0.9788
# Epoch 33: val_loss improved from 0.45138 to 0.45132, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 60s 1s/step - loss: 0.3148 - accuracy: 0.9788 - val_loss: 0.4513 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 34/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3102 - accuracy: 0.9815
# Epoch 34: val_loss improved from 0.45132 to 0.44950, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 57s 1s/step - loss: 0.3102 - accuracy: 0.9815 - val_loss: 0.4495 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 35/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3057 - accuracy: 0.9813
# Epoch 35: val_loss improved from 0.44950 to 0.44360, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.3057 - accuracy: 0.9813 - val_loss: 0.4436 - val_accuracy: 0.8350 - lr: 1.0000e-04
# Epoch 36/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3035 - accuracy: 0.9802
# Epoch 36: val_loss improved from 0.44360 to 0.44271, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 58s 1s/step - loss: 0.3035 - accuracy: 0.9802 - val_loss: 0.4427 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 37/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 0.9819
# Epoch 37: val_loss did not improve from 0.44271
# 41/41 [==============================] - 18s 438ms/step - loss: 0.2981 - accuracy: 0.9819 - val_loss: 0.4460 - val_accuracy: 0.8369 - lr: 1.0000e-04
# Epoch 38/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9817
# Epoch 38: val_loss improved from 0.44271 to 0.43682, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.2960 - accuracy: 0.9817 - val_loss: 0.4368 - val_accuracy: 0.8457 - lr: 1.0000e-04
# Epoch 39/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.9842
# Epoch 39: val_loss did not improve from 0.43682
# 41/41 [==============================] - 17s 423ms/step - loss: 0.2918 - accuracy: 0.9842 - val_loss: 0.4380 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 40/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.9827
# Epoch 40: val_loss did not improve from 0.43682
# 41/41 [==============================] - 17s 411ms/step - loss: 0.2881 - accuracy: 0.9827 - val_loss: 0.4400 - val_accuracy: 0.8369 - lr: 1.0000e-04
# Epoch 41/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.9834
# Epoch 41: val_loss did not improve from 0.43682
# 41/41 [==============================] - 17s 409ms/step - loss: 0.2883 - accuracy: 0.9834 - val_loss: 0.4371 - val_accuracy: 0.8379 - lr: 1.0000e-04
# Epoch 42/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.9846
# Epoch 42: val_loss improved from 0.43682 to 0.43395, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.2808 - accuracy: 0.9846 - val_loss: 0.4340 - val_accuracy: 0.8379 - lr: 1.0000e-04
# Epoch 43/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.9830
# Epoch 43: val_loss improved from 0.43395 to 0.42806, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 57s 1s/step - loss: 0.2803 - accuracy: 0.9830 - val_loss: 0.4281 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 44/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9870
# Epoch 44: val_loss did not improve from 0.42806
# 41/41 [==============================] - 17s 424ms/step - loss: 0.2745 - accuracy: 0.9870 - val_loss: 0.4287 - val_accuracy: 0.8457 - lr: 1.0000e-04
# Epoch 45/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9859
# Epoch 45: val_loss improved from 0.42806 to 0.42226, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.2722 - accuracy: 0.9859 - val_loss: 0.4223 - val_accuracy: 0.8486 - lr: 1.0000e-04
# Epoch 46/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2673 - accuracy: 0.9867
# Epoch 46: val_loss did not improve from 0.42226
# 41/41 [==============================] - 17s 427ms/step - loss: 0.2673 - accuracy: 0.9867 - val_loss: 0.4252 - val_accuracy: 0.8359 - lr: 1.0000e-04
# Epoch 47/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.9853
# Epoch 47: val_loss improved from 0.42226 to 0.41763, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.2655 - accuracy: 0.9853 - val_loss: 0.4176 - val_accuracy: 0.8516 - lr: 1.0000e-04
# Epoch 48/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2631 - accuracy: 0.9842
# Epoch 48: val_loss did not improve from 0.41763
# 41/41 [==============================] - 17s 424ms/step - loss: 0.2631 - accuracy: 0.9842 - val_loss: 0.4186 - val_accuracy: 0.8467 - lr: 1.0000e-04
# Epoch 49/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9851
# Epoch 49: val_loss did not improve from 0.41763
# 41/41 [==============================] - 18s 436ms/step - loss: 0.2580 - accuracy: 0.9851 - val_loss: 0.4243 - val_accuracy: 0.8350 - lr: 1.0000e-04
# Epoch 50/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.9899
# Epoch 50: val_loss improved from 0.41763 to 0.41502, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 57s 1s/step - loss: 0.2536 - accuracy: 0.9899 - val_loss: 0.4150 - val_accuracy: 0.8398 - lr: 1.0000e-04
# Epoch 51/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9869
# Epoch 51: val_loss improved from 0.41502 to 0.41322, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.2540 - accuracy: 0.9869 - val_loss: 0.4132 - val_accuracy: 0.8398 - lr: 1.0000e-04
# Epoch 52/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9844
# Epoch 52: val_loss did not improve from 0.41322
# 41/41 [==============================] - 18s 430ms/step - loss: 0.2505 - accuracy: 0.9844 - val_loss: 0.4162 - val_accuracy: 0.8320 - lr: 1.0000e-04
# Epoch 53/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 0.9865
# Epoch 53: val_loss improved from 0.41322 to 0.41177, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.2477 - accuracy: 0.9865 - val_loss: 0.4118 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 54/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.9867
# Epoch 54: val_loss improved from 0.41177 to 0.40875, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 53s 1s/step - loss: 0.2444 - accuracy: 0.9867 - val_loss: 0.4087 - val_accuracy: 0.8457 - lr: 1.0000e-04
# Epoch 55/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.9889
# Epoch 55: val_loss did not improve from 0.40875
# 41/41 [==============================] - 17s 424ms/step - loss: 0.2402 - accuracy: 0.9889 - val_loss: 0.4142 - val_accuracy: 0.8350 - lr: 1.0000e-04
# Epoch 56/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9882
# Epoch 56: val_loss did not improve from 0.40875
# 41/41 [==============================] - 17s 412ms/step - loss: 0.2391 - accuracy: 0.9882 - val_loss: 0.4110 - val_accuracy: 0.8389 - lr: 1.0000e-04
# Epoch 57/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9895
# Epoch 57: val_loss improved from 0.40875 to 0.40777, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.2350 - accuracy: 0.9895 - val_loss: 0.4078 - val_accuracy: 0.8369 - lr: 1.0000e-04
# Epoch 58/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9880
# Epoch 58: val_loss improved from 0.40777 to 0.40209, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.2329 - accuracy: 0.9880 - val_loss: 0.4021 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 59/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9882
# Epoch 59: val_loss did not improve from 0.40209
# 41/41 [==============================] - 17s 427ms/step - loss: 0.2317 - accuracy: 0.9882 - val_loss: 0.4073 - val_accuracy: 0.8379 - lr: 1.0000e-04
# Epoch 60/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2264 - accuracy: 0.9901
# Epoch 60: val_loss did not improve from 0.40209
# 41/41 [==============================] - 17s 409ms/step - loss: 0.2264 - accuracy: 0.9901 - val_loss: 0.4080 - val_accuracy: 0.8350 - lr: 1.0000e-04
# Epoch 61/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9897
# Epoch 61: val_loss improved from 0.40209 to 0.39536, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.2249 - accuracy: 0.9897 - val_loss: 0.3954 - val_accuracy: 0.8486 - lr: 1.0000e-04
# Epoch 62/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.9895
# Epoch 62: val_loss did not improve from 0.39536
# 41/41 [==============================] - 17s 428ms/step - loss: 0.2221 - accuracy: 0.9895 - val_loss: 0.4039 - val_accuracy: 0.8379 - lr: 1.0000e-04
# Epoch 63/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9903
# Epoch 63: val_loss did not improve from 0.39536
# 41/41 [==============================] - 17s 408ms/step - loss: 0.2193 - accuracy: 0.9903 - val_loss: 0.4004 - val_accuracy: 0.8389 - lr: 1.0000e-04
# Epoch 64/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9891
# Epoch 64: val_loss did not improve from 0.39536
# 41/41 [==============================] - 20s 487ms/step - loss: 0.2181 - accuracy: 0.9891 - val_loss: 0.4027 - val_accuracy: 0.8379 - lr: 1.0000e-04
# Epoch 65/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2147 - accuracy: 0.9901
# Epoch 65: val_loss improved from 0.39536 to 0.38908, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 56s 1s/step - loss: 0.2147 - accuracy: 0.9901 - val_loss: 0.3891 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 66/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9910
# Epoch 66: val_loss did not improve from 0.38908
# 41/41 [==============================] - 18s 436ms/step - loss: 0.2118 - accuracy: 0.9910 - val_loss: 0.3956 - val_accuracy: 0.8389 - lr: 1.0000e-04
# Epoch 67/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9903
# Epoch 67: val_loss did not improve from 0.38908
# 41/41 [==============================] - 18s 446ms/step - loss: 0.2104 - accuracy: 0.9903 - val_loss: 0.3896 - val_accuracy: 0.8506 - lr: 1.0000e-04
# Epoch 68/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9920
# Epoch 68: val_loss did not improve from 0.38908
# 41/41 [==============================] - 17s 414ms/step - loss: 0.2065 - accuracy: 0.9920 - val_loss: 0.3943 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 69/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9907
# Epoch 69: val_loss did not improve from 0.38908
# 41/41 [==============================] - 17s 412ms/step - loss: 0.2054 - accuracy: 0.9907 - val_loss: 0.3914 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 70/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9905
# Epoch 70: val_loss did not improve from 0.38908
# 41/41 [==============================] - 17s 411ms/step - loss: 0.2032 - accuracy: 0.9905 - val_loss: 0.3918 - val_accuracy: 0.8447 - lr: 1.0000e-04
# Epoch 71/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9905
# Epoch 71: val_loss did not improve from 0.38908
# 41/41 [==============================] - 17s 413ms/step - loss: 0.2005 - accuracy: 0.9905 - val_loss: 0.3913 - val_accuracy: 0.8447 - lr: 1.0000e-04
# Epoch 72/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9907
# Epoch 72: val_loss did not improve from 0.38908
# 41/41 [==============================] - 17s 414ms/step - loss: 0.1981 - accuracy: 0.9907 - val_loss: 0.3919 - val_accuracy: 0.8447 - lr: 1.0000e-04
# Epoch 73/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9918
# Epoch 73: val_loss improved from 0.38908 to 0.38531, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 57s 1s/step - loss: 0.1956 - accuracy: 0.9918 - val_loss: 0.3853 - val_accuracy: 0.8408 - lr: 1.0000e-04
# Epoch 74/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9914
# Epoch 74: val_loss did not improve from 0.38531
# 41/41 [==============================] - 17s 427ms/step - loss: 0.1934 - accuracy: 0.9914 - val_loss: 0.3896 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 75/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9935
# Epoch 75: val_loss improved from 0.38531 to 0.38334, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.1899 - accuracy: 0.9935 - val_loss: 0.3833 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 76/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9918
# Epoch 76: val_loss did not improve from 0.38334
# 41/41 [==============================] - 17s 424ms/step - loss: 0.1903 - accuracy: 0.9918 - val_loss: 0.3847 - val_accuracy: 0.8477 - lr: 1.0000e-04
# Epoch 77/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9928
# Epoch 77: val_loss improved from 0.38334 to 0.38055, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.1864 - accuracy: 0.9928 - val_loss: 0.3805 - val_accuracy: 0.8506 - lr: 1.0000e-04
# Epoch 78/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9914
# Epoch 78: val_loss did not improve from 0.38055
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1853 - accuracy: 0.9914 - val_loss: 0.3843 - val_accuracy: 0.8457 - lr: 1.0000e-04
# Epoch 79/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9922
# Epoch 79: val_loss did not improve from 0.38055
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1828 - accuracy: 0.9922 - val_loss: 0.3880 - val_accuracy: 0.8320 - lr: 1.0000e-04
# Epoch 80/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9929
# Epoch 80: val_loss improved from 0.38055 to 0.37990, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.1804 - accuracy: 0.9929 - val_loss: 0.3799 - val_accuracy: 0.8447 - lr: 1.0000e-04
# Epoch 81/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9928
# Epoch 81: val_loss did not improve from 0.37990
# 41/41 [==============================] - 17s 429ms/step - loss: 0.1786 - accuracy: 0.9928 - val_loss: 0.3837 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 82/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9924
# Epoch 82: val_loss improved from 0.37990 to 0.37984, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 57s 1s/step - loss: 0.1774 - accuracy: 0.9924 - val_loss: 0.3798 - val_accuracy: 0.8340 - lr: 1.0000e-04
# Epoch 83/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9943
# Epoch 83: val_loss improved from 0.37984 to 0.37961, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 55s 1s/step - loss: 0.1733 - accuracy: 0.9943 - val_loss: 0.3796 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 84/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9914
# Epoch 84: val_loss improved from 0.37961 to 0.37116, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 54s 1s/step - loss: 0.1745 - accuracy: 0.9914 - val_loss: 0.3712 - val_accuracy: 0.8535 - lr: 1.0000e-04
# Epoch 85/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9935
# Epoch 85: val_loss improved from 0.37116 to 0.37018, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 62s 2s/step - loss: 0.1705 - accuracy: 0.9935 - val_loss: 0.3702 - val_accuracy: 0.8525 - lr: 1.0000e-04
# Epoch 86/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9926
# Epoch 86: val_loss did not improve from 0.37018
# 41/41 [==============================] - 18s 432ms/step - loss: 0.1693 - accuracy: 0.9926 - val_loss: 0.3785 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 87/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9928
# Epoch 87: val_loss did not improve from 0.37018
# 41/41 [==============================] - 17s 418ms/step - loss: 0.1669 - accuracy: 0.9928 - val_loss: 0.3750 - val_accuracy: 0.8477 - lr: 1.0000e-04
# Epoch 88/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1647 - accuracy: 0.9947
# Epoch 88: val_loss did not improve from 0.37018
# 41/41 [==============================] - 17s 418ms/step - loss: 0.1647 - accuracy: 0.9947 - val_loss: 0.3764 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 89/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9926
# Epoch 89: val_loss did not improve from 0.37018
# 41/41 [==============================] - 17s 414ms/step - loss: 0.1643 - accuracy: 0.9926 - val_loss: 0.3732 - val_accuracy: 0.8486 - lr: 1.0000e-04
# Epoch 90/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9937
# Epoch 90: val_loss did not improve from 0.37018
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1609 - accuracy: 0.9937 - val_loss: 0.3721 - val_accuracy: 0.8506 - lr: 1.0000e-04
# Epoch 91/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1590 - accuracy: 0.9933
# Epoch 91: val_loss improved from 0.37018 to 0.36092, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/Ensemble/ensamble_densenet201_xception_seresnext101_inceptionv3/model.h5
# 41/41 [==============================] - 58s 1s/step - loss: 0.1590 - accuracy: 0.9933 - val_loss: 0.3609 - val_accuracy: 0.8604 - lr: 1.0000e-04
# Epoch 92/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9931
# Epoch 92: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 429ms/step - loss: 0.1582 - accuracy: 0.9931 - val_loss: 0.3732 - val_accuracy: 0.8477 - lr: 1.0000e-04
# Epoch 93/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9935
# Epoch 93: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 413ms/step - loss: 0.1567 - accuracy: 0.9935 - val_loss: 0.3706 - val_accuracy: 0.8408 - lr: 1.0000e-04
# Epoch 94/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9947
# Epoch 94: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 410ms/step - loss: 0.1532 - accuracy: 0.9947 - val_loss: 0.3687 - val_accuracy: 0.8477 - lr: 1.0000e-04
# Epoch 95/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9941
# Epoch 95: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1525 - accuracy: 0.9941 - val_loss: 0.3636 - val_accuracy: 0.8525 - lr: 1.0000e-04
# Epoch 96/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9945
# Epoch 96: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1511 - accuracy: 0.9945 - val_loss: 0.3633 - val_accuracy: 0.8525 - lr: 1.0000e-04
# Epoch 97/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9952
# Epoch 97: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 407ms/step - loss: 0.1495 - accuracy: 0.9952 - val_loss: 0.3646 - val_accuracy: 0.8516 - lr: 1.0000e-04
# Epoch 98/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9931
# Epoch 98: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1485 - accuracy: 0.9931 - val_loss: 0.3685 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 99/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9947
# Epoch 99: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1455 - accuracy: 0.9947 - val_loss: 0.3641 - val_accuracy: 0.8525 - lr: 1.0000e-04
# Epoch 100/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9943
# Epoch 100: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 408ms/step - loss: 0.1451 - accuracy: 0.9943 - val_loss: 0.3675 - val_accuracy: 0.8525 - lr: 1.0000e-04
# Epoch 101/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9949
# Epoch 101: val_loss did not improve from 0.36092
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1424 - accuracy: 0.9949 - val_loss: 0.3765 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 102/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9950
# Epoch 102: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 409ms/step - loss: 0.1414 - accuracy: 0.9950 - val_loss: 0.3646 - val_accuracy: 0.8516 - lr: 1.0000e-05
# Epoch 103/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9939
# Epoch 103: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 409ms/step - loss: 0.1420 - accuracy: 0.9939 - val_loss: 0.3674 - val_accuracy: 0.8457 - lr: 1.0000e-05
# Epoch 104/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9949
# Epoch 104: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 411ms/step - loss: 0.1408 - accuracy: 0.9949 - val_loss: 0.3642 - val_accuracy: 0.8486 - lr: 1.0000e-05
# Epoch 105/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9952
# Epoch 105: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 410ms/step - loss: 0.1411 - accuracy: 0.9952 - val_loss: 0.3653 - val_accuracy: 0.8457 - lr: 1.0000e-05
# Epoch 106/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9950
# Epoch 106: val_loss did not improve from 0.36092
# 41/41 [==============================] - 17s 407ms/step - loss: 0.1409 - accuracy: 0.9950 - val_loss: 0.3681 - val_accuracy: 0.8496 - lr: 1.0000e-05
# Epoch 106: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history 
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 8/8 [==============================] - 3s 317ms/step - loss: 0.4125 - accuracy: 0.8496
# {'accuracy': 0.849609375, 'loss': 0.4124618172645569}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
report =classification_report(gts, preds, target_names=LABELS,output_dict=True)
report
# Out:
# {'Brain': {'f1-score': 0.8477611940298507,
#   'precision': 0.8711656441717791,
#   'recall': 0.8255813953488372,
#   'support': 516},
#  'No_tumor': {'f1-score': 0.8533077660594439,
#   'precision': 0.8317757009345794,
#   'recall': 0.8759842519685039,
#   'support': 508},
#  'accuracy': 0.8505859375,
#  'macro avg': {'f1-score': 0.8505344800446473,
#   'precision': 0.8514706725531793,
#   'recall': 0.8507828236586705,
#   'support': 1024},
#  'weighted avg': {'f1-score': 0.8505128137476567,
#   'precision': 0.8516245395189496,
#   'recall': 0.8505859375,
#   'support': 1024}}

# %%
import json
with open(os.path.join(MODEL_DIR,f"report_{MODEL_NAME}.json"), 'w') as fp:
    json.dump(report, fp)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat, 
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (20,20))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()

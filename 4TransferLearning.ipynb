# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-40a5903b88ccf81a4b5dca6b4c513f3203dec43a0013d239ec2a40a2' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/cnn/local/brain_tumor/
# Out:
# /content/drive/MyDrive/cnn/local/brain_tumor

# %%
ls -la
# Out:
# total 17
# -rw------- 1 root root  182 May  9 17:59 config.json
# drwx------ 2 root root 4096 May  9 17:42 Ensemble/
# drwx------ 2 root root 4096 May 10 06:08 MODEL_DIR/
# drwx------ 2 root root 4096 Jun  5 16:50 models/
# drwx------ 2 root root 4096 May 10 09:12 MODELS/

# %% [markdown]
# # PARAMETERS

# %%
import os 
GCS_PATH    =    'gs://kds-40a5903b88ccf81a4b5dca6b4c513f3203dec43a0013d239ec2a40a2'
MODEL_NAME  =    "densenet201" # @param ["vgg16", "vgg19", "EfficientNetB7", "vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/braintumor/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048  
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}') 

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-40a5903b88ccf81a4b5dca6b4c513f3203dec43a0013d239ec2a40a2/content/drive/MyDrive/braintumor/tfrecords
# /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['Brain', 'No_tumor'],
#  'nb_channels': 3,
#  'nb_classes': 2,
#  'nb_eval_data': 1120,
#  'nb_train_data': 5296}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf 
import os 


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.8.2
# Running on TPU  grpc://10.80.5.58:8470
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.80.5.58:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.80.5.58:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 41 8

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode): 
    '''
      This Function generates data from gcs
    '''
    
    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }    
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))
        
        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 2)
# tf.Tensor([0. 1.], shape=(2,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True, 
                                                  verbose=1, 
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15, 
                                                  verbose=1, 
                                                  mode = 'auto') 

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn
with strategy.scope():
    if "EfficientNet" not in MODEL_NAME:
      classifier, _ = Classifiers.get(MODEL_NAME)
    else:
      classifier=getattr(efn,MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights="imagenet")
    # freeze layers
    for layer in net.layers:
      layer.trainable = False
    inp=net.input
    x=net.output
    # modeling
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 128, 128, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 128, 128, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 130, 130, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 64, 64, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 64, 64, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 64, 64, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 64, 64, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 64, 64, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 64, 64, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 64, 64, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 64, 64, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 64, 64, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 64, 64, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 64, 64, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 64, 64, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 64, 64, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 32, 32, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 32, 32, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 32, 32, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 32, 32, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 32, 32, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 32, 32, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 32, 32, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 32, 32, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 32, 32, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 32, 32, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 32, 32, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 32, 32, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 32, 32, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 32, 32, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 32, 32, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 32, 32, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 32, 32, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 32, 32, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 32, 32, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 32, 32, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 32, 32, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 32, 32, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 32, 32, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 32, 32, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 32, 32, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 16, 16, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 16, 16, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 16, 16, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 16, 16, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 16, 16, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 16, 16, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 16, 16, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 16, 16, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
# ...
#  conv5_block25_1_conv (Conv2D)  (None, 8, 8, 128)    212992      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 8, 8, 1696)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 8, 8, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 8, 8, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 8, 8, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 8, 8, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 8, 8, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 8, 8, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 8, 8, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 8, 8, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 8, 8, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 8, 8, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 8, 8, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 8, 8, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 8, 8, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 8, 8, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 8, 8, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 8, 8, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 8, 8, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 8, 8, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 8, 8, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 8, 8, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 8, 8, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 8, 8, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 8, 8, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 8, 8, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 8, 8, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 8, 8, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 8, 8, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 8, 8, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 8, 8, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 8, 8, 1920)   0           ['bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1920)        0           ['relu[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1920)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 2)            3842        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 18,325,826
# Trainable params: 3,842
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch= STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1, 
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 41/41 [==============================] - ETA: 0s - loss: 0.6899 - accuracy: 0.5941
# Epoch 1: val_loss improved from inf to 0.63347, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 73s 884ms/step - loss: 0.6899 - accuracy: 0.5941 - val_loss: 0.6335 - val_accuracy: 0.6504 - lr: 1.0000e-04
# Epoch 2/250
# 41/41 [==============================] - ETA: 0s - loss: 0.5704 - accuracy: 0.7092
# Epoch 2: val_loss improved from 0.63347 to 0.57454, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 336ms/step - loss: 0.5704 - accuracy: 0.7092 - val_loss: 0.5745 - val_accuracy: 0.7061 - lr: 1.0000e-04
# Epoch 3/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.7904
# Epoch 3: val_loss improved from 0.57454 to 0.52580, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 347ms/step - loss: 0.4828 - accuracy: 0.7904 - val_loss: 0.5258 - val_accuracy: 0.7529 - lr: 1.0000e-04
# Epoch 4/250
# 41/41 [==============================] - ETA: 0s - loss: 0.4230 - accuracy: 0.8388
# Epoch 4: val_loss improved from 0.52580 to 0.49066, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 343ms/step - loss: 0.4230 - accuracy: 0.8388 - val_loss: 0.4907 - val_accuracy: 0.7891 - lr: 1.0000e-04
# Epoch 5/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3715 - accuracy: 0.8674
# Epoch 5: val_loss improved from 0.49066 to 0.46272, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 311ms/step - loss: 0.3715 - accuracy: 0.8674 - val_loss: 0.4627 - val_accuracy: 0.8086 - lr: 1.0000e-04
# Epoch 6/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.8811
# Epoch 6: val_loss improved from 0.46272 to 0.44703, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 326ms/step - loss: 0.3412 - accuracy: 0.8811 - val_loss: 0.4470 - val_accuracy: 0.8154 - lr: 1.0000e-04
# Epoch 7/250
# 41/41 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.8977
# Epoch 7: val_loss improved from 0.44703 to 0.42726, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 12s 310ms/step - loss: 0.3149 - accuracy: 0.8977 - val_loss: 0.4273 - val_accuracy: 0.8301 - lr: 1.0000e-04
# Epoch 8/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.9053
# Epoch 8: val_loss improved from 0.42726 to 0.41666, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 316ms/step - loss: 0.2878 - accuracy: 0.9053 - val_loss: 0.4167 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 9/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.9194
# Epoch 9: val_loss improved from 0.41666 to 0.40369, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 326ms/step - loss: 0.2695 - accuracy: 0.9194 - val_loss: 0.4037 - val_accuracy: 0.8486 - lr: 1.0000e-04
# Epoch 10/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9232
# Epoch 10: val_loss improved from 0.40369 to 0.39605, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 317ms/step - loss: 0.2541 - accuracy: 0.9232 - val_loss: 0.3961 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 11/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9284
# Epoch 11: val_loss improved from 0.39605 to 0.38779, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 312ms/step - loss: 0.2399 - accuracy: 0.9284 - val_loss: 0.3878 - val_accuracy: 0.8574 - lr: 1.0000e-04
# Epoch 12/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9339
# Epoch 12: val_loss improved from 0.38779 to 0.38192, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 315ms/step - loss: 0.2260 - accuracy: 0.9339 - val_loss: 0.3819 - val_accuracy: 0.8594 - lr: 1.0000e-04
# Epoch 13/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2182 - accuracy: 0.9329
# Epoch 13: val_loss improved from 0.38192 to 0.37378, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 315ms/step - loss: 0.2182 - accuracy: 0.9329 - val_loss: 0.3738 - val_accuracy: 0.8633 - lr: 1.0000e-04
# Epoch 14/250
# 41/41 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9383
# Epoch 14: val_loss did not improve from 0.37378
# 41/41 [==============================] - 5s 129ms/step - loss: 0.2079 - accuracy: 0.9383 - val_loss: 0.3746 - val_accuracy: 0.8584 - lr: 1.0000e-04
# Epoch 15/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9430
# Epoch 15: val_loss improved from 0.37378 to 0.36189, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 355ms/step - loss: 0.1973 - accuracy: 0.9430 - val_loss: 0.3619 - val_accuracy: 0.8604 - lr: 1.0000e-04
# Epoch 16/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9413
# Epoch 16: val_loss improved from 0.36189 to 0.35922, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 336ms/step - loss: 0.1934 - accuracy: 0.9413 - val_loss: 0.3592 - val_accuracy: 0.8643 - lr: 1.0000e-04
# Epoch 17/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1865 - accuracy: 0.9472
# Epoch 17: val_loss did not improve from 0.35922
# 41/41 [==============================] - 5s 133ms/step - loss: 0.1865 - accuracy: 0.9472 - val_loss: 0.3651 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Epoch 18/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9489
# Epoch 18: val_loss did not improve from 0.35922
# 41/41 [==============================] - 6s 136ms/step - loss: 0.1792 - accuracy: 0.9489 - val_loss: 0.3670 - val_accuracy: 0.8682 - lr: 1.0000e-04
# Epoch 19/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1757 - accuracy: 0.9474
# Epoch 19: val_loss did not improve from 0.35922
# 41/41 [==============================] - 5s 134ms/step - loss: 0.1757 - accuracy: 0.9474 - val_loss: 0.3592 - val_accuracy: 0.8662 - lr: 1.0000e-04
# Epoch 20/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9560
# Epoch 20: val_loss improved from 0.35922 to 0.35688, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 349ms/step - loss: 0.1625 - accuracy: 0.9560 - val_loss: 0.3569 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 21/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9545
# Epoch 21: val_loss improved from 0.35688 to 0.34860, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 332ms/step - loss: 0.1600 - accuracy: 0.9545 - val_loss: 0.3486 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Epoch 22/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9550
# Epoch 22: val_loss improved from 0.34860 to 0.34818, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 344ms/step - loss: 0.1584 - accuracy: 0.9550 - val_loss: 0.3482 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Epoch 23/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.9545
# Epoch 23: val_loss did not improve from 0.34818
# 41/41 [==============================] - 6s 136ms/step - loss: 0.1546 - accuracy: 0.9545 - val_loss: 0.3524 - val_accuracy: 0.8691 - lr: 1.0000e-04
# Epoch 24/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9546
# Epoch 24: val_loss did not improve from 0.34818
# 41/41 [==============================] - 6s 139ms/step - loss: 0.1518 - accuracy: 0.9546 - val_loss: 0.3523 - val_accuracy: 0.8691 - lr: 1.0000e-04
# Epoch 25/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1430 - accuracy: 0.9594
# Epoch 25: val_loss did not improve from 0.34818
# 41/41 [==============================] - 5s 131ms/step - loss: 0.1430 - accuracy: 0.9594 - val_loss: 0.3557 - val_accuracy: 0.8682 - lr: 1.0000e-04
# Epoch 26/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9587
# Epoch 26: val_loss improved from 0.34818 to 0.34802, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 345ms/step - loss: 0.1454 - accuracy: 0.9587 - val_loss: 0.3480 - val_accuracy: 0.8740 - lr: 1.0000e-04
# Epoch 27/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9598
# Epoch 27: val_loss did not improve from 0.34802
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1381 - accuracy: 0.9598 - val_loss: 0.3501 - val_accuracy: 0.8711 - lr: 1.0000e-04
# Epoch 28/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9627
# Epoch 28: val_loss did not improve from 0.34802
# 41/41 [==============================] - 6s 138ms/step - loss: 0.1353 - accuracy: 0.9627 - val_loss: 0.3558 - val_accuracy: 0.8652 - lr: 1.0000e-04
# Epoch 29/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9621
# Epoch 29: val_loss did not improve from 0.34802
# 41/41 [==============================] - 5s 132ms/step - loss: 0.1309 - accuracy: 0.9621 - val_loss: 0.3528 - val_accuracy: 0.8711 - lr: 1.0000e-04
# Epoch 30/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9630
# Epoch 30: val_loss did not improve from 0.34802
# 41/41 [==============================] - 5s 131ms/step - loss: 0.1335 - accuracy: 0.9630 - val_loss: 0.3534 - val_accuracy: 0.8652 - lr: 1.0000e-04
# Epoch 31/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9646
# Epoch 31: val_loss improved from 0.34802 to 0.34311, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 327ms/step - loss: 0.1247 - accuracy: 0.9646 - val_loss: 0.3431 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Epoch 32/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9640
# Epoch 32: val_loss did not improve from 0.34311
# 41/41 [==============================] - 5s 131ms/step - loss: 0.1258 - accuracy: 0.9640 - val_loss: 0.3476 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 33/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9646
# Epoch 33: val_loss improved from 0.34311 to 0.34254, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 14s 351ms/step - loss: 0.1234 - accuracy: 0.9646 - val_loss: 0.3425 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 34/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9632
# Epoch 34: val_loss did not improve from 0.34254
# 41/41 [==============================] - 6s 138ms/step - loss: 0.1236 - accuracy: 0.9632 - val_loss: 0.3468 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 35/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9674
# Epoch 35: val_loss did not improve from 0.34254
# 41/41 [==============================] - 6s 141ms/step - loss: 0.1153 - accuracy: 0.9674 - val_loss: 0.3525 - val_accuracy: 0.8682 - lr: 1.0000e-04
# Epoch 36/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9663
# Epoch 36: val_loss did not improve from 0.34254
# 41/41 [==============================] - 5s 132ms/step - loss: 0.1169 - accuracy: 0.9663 - val_loss: 0.3485 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Epoch 37/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9676
# Epoch 37: val_loss did not improve from 0.34254
# 41/41 [==============================] - 5s 127ms/step - loss: 0.1141 - accuracy: 0.9676 - val_loss: 0.3501 - val_accuracy: 0.8691 - lr: 1.0000e-04
# Epoch 38/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9684
# Epoch 38: val_loss did not improve from 0.34254
# 41/41 [==============================] - 5s 129ms/step - loss: 0.1104 - accuracy: 0.9684 - val_loss: 0.3464 - val_accuracy: 0.8691 - lr: 1.0000e-04
# Epoch 39/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9670
# Epoch 39: val_loss did not improve from 0.34254
# 41/41 [==============================] - 5s 130ms/step - loss: 0.1126 - accuracy: 0.9670 - val_loss: 0.3466 - val_accuracy: 0.8701 - lr: 1.0000e-04
# Epoch 40/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9691
# Epoch 40: val_loss did not improve from 0.34254
# 41/41 [==============================] - 5s 126ms/step - loss: 0.1098 - accuracy: 0.9691 - val_loss: 0.3506 - val_accuracy: 0.8662 - lr: 1.0000e-04
# Epoch 41/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9684
# Epoch 41: val_loss did not improve from 0.34254
# 41/41 [==============================] - 5s 129ms/step - loss: 0.1064 - accuracy: 0.9684 - val_loss: 0.3505 - val_accuracy: 0.8672 - lr: 1.0000e-04
# Epoch 42/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9739
# Epoch 42: val_loss did not improve from 0.34254
# 41/41 [==============================] - 5s 134ms/step - loss: 0.1023 - accuracy: 0.9739 - val_loss: 0.3522 - val_accuracy: 0.8740 - lr: 1.0000e-04
# Epoch 43/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9712
# Epoch 43: val_loss improved from 0.34254 to 0.33406, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 315ms/step - loss: 0.1034 - accuracy: 0.9712 - val_loss: 0.3341 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 44/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9743
# Epoch 44: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 128ms/step - loss: 0.1001 - accuracy: 0.9743 - val_loss: 0.3501 - val_accuracy: 0.8652 - lr: 1.0000e-04
# Epoch 45/250
# 41/41 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9724
# Epoch 45: val_loss did not improve from 0.33406
# 41/41 [==============================] - 6s 151ms/step - loss: 0.1017 - accuracy: 0.9724 - val_loss: 0.3487 - val_accuracy: 0.8711 - lr: 1.0000e-04
# Epoch 46/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9718
# Epoch 46: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 130ms/step - loss: 0.0960 - accuracy: 0.9718 - val_loss: 0.3433 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Epoch 47/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9728
# Epoch 47: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 132ms/step - loss: 0.0959 - accuracy: 0.9728 - val_loss: 0.3341 - val_accuracy: 0.8789 - lr: 1.0000e-04
# Epoch 48/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9739
# Epoch 48: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 130ms/step - loss: 0.0927 - accuracy: 0.9739 - val_loss: 0.3544 - val_accuracy: 0.8682 - lr: 1.0000e-04
# Epoch 49/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0907 - accuracy: 0.9756
# Epoch 49: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 130ms/step - loss: 0.0907 - accuracy: 0.9756 - val_loss: 0.3572 - val_accuracy: 0.8691 - lr: 1.0000e-04
# Epoch 50/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9773
# Epoch 50: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 131ms/step - loss: 0.0885 - accuracy: 0.9773 - val_loss: 0.3542 - val_accuracy: 0.8643 - lr: 1.0000e-04
# Epoch 51/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9710
# Epoch 51: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0963 - accuracy: 0.9710 - val_loss: 0.3476 - val_accuracy: 0.8740 - lr: 1.0000e-04
# Epoch 52/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9754
# Epoch 52: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 131ms/step - loss: 0.0898 - accuracy: 0.9754 - val_loss: 0.3349 - val_accuracy: 0.8799 - lr: 1.0000e-04
# Epoch 53/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9766
# Epoch 53: val_loss did not improve from 0.33406
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0881 - accuracy: 0.9766 - val_loss: 0.3493 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 54/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9743
# Epoch 54: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0930 - accuracy: 0.9743 - val_loss: 0.3441 - val_accuracy: 0.8770 - lr: 1.0000e-05
# Epoch 55/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9758
# Epoch 55: val_loss did not improve from 0.33406
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0862 - accuracy: 0.9758 - val_loss: 0.3385 - val_accuracy: 0.8770 - lr: 1.0000e-05
# Epoch 56/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9771
# Epoch 56: val_loss improved from 0.33406 to 0.33307, saving model to /content/drive/MyDrive/cnn/local/brain_tumor/models/densenet201/densenet201.h5
# 41/41 [==============================] - 13s 313ms/step - loss: 0.0849 - accuracy: 0.9771 - val_loss: 0.3331 - val_accuracy: 0.8730 - lr: 1.0000e-05
# Epoch 57/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9760
# Epoch 57: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0886 - accuracy: 0.9760 - val_loss: 0.3538 - val_accuracy: 0.8721 - lr: 1.0000e-05
# Epoch 58/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9747
# Epoch 58: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 135ms/step - loss: 0.0863 - accuracy: 0.9747 - val_loss: 0.3505 - val_accuracy: 0.8711 - lr: 1.0000e-05
# Epoch 59/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9762
# Epoch 59: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 130ms/step - loss: 0.0865 - accuracy: 0.9762 - val_loss: 0.3474 - val_accuracy: 0.8701 - lr: 1.0000e-05
# Epoch 60/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9758
# Epoch 60: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0895 - accuracy: 0.9758 - val_loss: 0.3474 - val_accuracy: 0.8711 - lr: 1.0000e-05
# Epoch 61/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9760
# Epoch 61: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 128ms/step - loss: 0.0878 - accuracy: 0.9760 - val_loss: 0.3410 - val_accuracy: 0.8740 - lr: 1.0000e-05
# Epoch 62/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9771
# Epoch 62: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 127ms/step - loss: 0.0839 - accuracy: 0.9771 - val_loss: 0.3599 - val_accuracy: 0.8662 - lr: 1.0000e-05
# Epoch 63/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9771
# Epoch 63: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 128ms/step - loss: 0.0860 - accuracy: 0.9771 - val_loss: 0.3507 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Epoch 64/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9728
# Epoch 64: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0898 - accuracy: 0.9728 - val_loss: 0.3517 - val_accuracy: 0.8701 - lr: 1.0000e-05
# Epoch 65/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9766
# Epoch 65: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0876 - accuracy: 0.9766 - val_loss: 0.3587 - val_accuracy: 0.8682 - lr: 1.0000e-05
# Epoch 66/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9769
# Epoch 66: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0839 - accuracy: 0.9769 - val_loss: 0.3345 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Epoch 67/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9750
# Epoch 67: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 129ms/step - loss: 0.0885 - accuracy: 0.9750 - val_loss: 0.3469 - val_accuracy: 0.8740 - lr: 1.0000e-05
# Epoch 68/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9785
# Epoch 68: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 130ms/step - loss: 0.0827 - accuracy: 0.9785 - val_loss: 0.3442 - val_accuracy: 0.8740 - lr: 1.0000e-05
# Epoch 69/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9762
# Epoch 69: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 132ms/step - loss: 0.0844 - accuracy: 0.9762 - val_loss: 0.3409 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Epoch 70/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9768
# Epoch 70: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 131ms/step - loss: 0.0859 - accuracy: 0.9768 - val_loss: 0.3418 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Epoch 71/250
# 41/41 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9718
# Epoch 71: val_loss did not improve from 0.33307
# 41/41 [==============================] - 5s 131ms/step - loss: 0.0883 - accuracy: 0.9718 - val_loss: 0.3416 - val_accuracy: 0.8740 - lr: 1.0000e-05
# Epoch 71: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history 
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 8/8 [==============================] - 2s 96ms/step - loss: 0.4768 - accuracy: 0.8496
# {'accuracy': 0.849609375, 'loss': 0.4768483638763428}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
report =classification_report(gts, preds, target_names=LABELS,output_dict=True)
report
# Out:
# {'Brain': {'f1-score': 0.8743914313534568,
#   'precision': 0.8634615384615385,
#   'recall': 0.8856015779092702,
#   'support': 507},
#  'No_tumor': {'f1-score': 0.8736532810969638,
#   'precision': 0.8849206349206349,
#   'recall': 0.8626692456479691,
#   'support': 517},
#  'accuracy': 0.8740234375,
#  'macro avg': {'f1-score': 0.8740223562252103,
#   'precision': 0.8741910866910867,
#   'recall': 0.8741354117786196,
#   'support': 1024},
#  'weighted avg': {'f1-score': 0.8740187519759111,
#   'precision': 0.8742958674355159,
#   'recall': 0.8740234375,
#   'support': 1024}}

# %%
import json
with open(os.path.join(MODEL_DIR,f"report_{MODEL_NAME}.json"), 'w') as fp:
    json.dump(report, fp)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat, 
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (20,20))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
